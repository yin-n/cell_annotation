# %% [markdown]
# ### Check data

# %% [markdown]
# #### load test file

# %%
import json
json_file_path = './test_files.json'

# read test json file
with open(json_file_path) as f:
    test_data = json.load(f)

# # filter norm test data
test_files = [f for f in test_data if '*img.tif' in f]

# %%
# Define a function to recursively search for matching strings

import json
import fnmatch
def find_matching_strings(obj, pattern):
    matches = []
    if isinstance(obj, dict):
        for key, value in obj.items():
            matches.extend(find_matching_strings(value, pattern))
    elif isinstance(obj, list):
        for item in obj:
            matches.extend(find_matching_strings(item, pattern))
    elif isinstance(obj, str):
        if fnmatch.fnmatch(obj, pattern):
            matches.append(obj)
    return matches

# Define the pattern to match
pattern = '*img.tif'

# Find all matching strings in the JSON data
matching_strings = find_matching_strings(test_data, pattern)

# %%
test_id = [item.split('_')[0] for item in matching_strings]
test_id = sorted(test_id, key=int)

# %%
import pickle
with open('./shuffle_model.pkl', 'rb') as f:
    shuffle_model = pickle.load(f)

# %% [markdown]
# #### Check whether the saved image aligns with original image shuffle order

# %%
# you need to change path to your pkl path
with open('./cellpose_nonorm_all.pkl', 'rb') as f:
    cellpose_data = pickle.load(f)

# %%
with open('./stardist_all.pkl', 'rb') as f:
    stardist_data = pickle.load(f)

# %%
with open('./swin2d.pkl', 'rb') as f:
    swin2d_predict = pickle.load(f)

# %%
with open('./swin3d_win3.pkl', 'rb') as f:
    swin_3D_pretrain_window3_predict = pickle.load(f)

# %%
models_map = {
    1:cellpose_data,
    2:stardist_data,
    3:swin2d_predict,
    4:swin_3D_pretrain_window3_predict
}

# %%
import tiffile as tf
import numpy as np
for img_id in test_id:
    model1_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model1.tif')
    model2_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model2.tif')
    model3_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model3.tif')
    model4_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model4.tif')
    model_ori1 = models_map[shuffle_model[img_id][0]][img_id]
    model_ori2 = models_map[shuffle_model[img_id][1]][img_id]
    model_ori3 = models_map[shuffle_model[img_id][2]][img_id]
    model_ori4 = models_map[shuffle_model[img_id][3]][img_id]
    are_equal1 = np.array_equal(model1_img, model_ori1)
    are_equal2 = np.array_equal(model2_img, model_ori2)
    are_equal3 = np.array_equal(model3_img, model_ori3)
    are_equal4 = np.array_equal(model4_img, model_ori4)
    if are_equal1 and are_equal2 and are_equal3 and are_equal4:
        print(img_id, 'same')
# Out:
# 0017 same
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_421104/2041197822.py in ?()
#       1 import tiffile as tf
#       2 import numpy as np
#       3 for img_id in test_id:
# ----> 4     model1_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model1.tif')
#       5     model2_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model2.tif')
#       6     model3_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model3.tif')
#       7     model4_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model4.tif')
#
# ~/miniconda3/envs/annotate/lib/python3.10/site-packages/tifffile/tifffile.py in ?(***failed resolving arguments***)
#    1220
#    1221         if isinstance(files, str) or not isinstance(
#    1222             files, collections.abc.Sequence
#    1223         ):
# -> 1224             with TiffFile(
#    1225                 files,
#    1226                 mode=mode,
#    1227                 name=name,
#
# ~/miniconda3/envs/annotate/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, file, mode, name, offset, size, omexml, _multifile, _useframes, _parent, **is_flags)
#    4259                 raise ValueError('invalid OME-XML')
#    4260             self._omexml = omexml
#    4261             self.is_ome = True
#    4262
# -> 4263         fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#    4264         self._fh = fh
#    4265         self._multifile = True if _multifile is None else bool(_multifile)
#    4266         self._files = {fh.name: self}
#
# ~/miniconda3/envs/annotate/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, file, mode, name, offset, size)
#   14644         self._offset = -1 if offset is None else offset
#   14645         self._size = -1 if size is None else size
#   14646         self._close = True
#   14647         self._lock = NullContext()
# > 14648         self.open()
#   14649         assert self._fh is not None
#
# ~/miniconda3/envs/annotate/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self)
#   14663             if self._mode not in {'rb', 'r+b', 'wb', 'xb'}:
#   14664                 raise ValueError(f'invalid mode {self._mode}')
#   14665             self._file = os.path.realpath(self._file)
#   14666             self._dir, self._name = os.path.split(self._file)
# > 14667             self._fh = open(
#   14668                 self._file, self._mode, encoding=None
#   14669             )  # type: ignore
#   14670             self._close = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/aperto/mxia/Tatz_annotations/models_select/0022_model1.tif'

# %%
models_name = {
    1:'cellpose',
    2:'stardist',
    3:'swin2d',
    4:'swin_3d_pretrain_win3'
}

# %%
import matplotlib.pyplot as plt 
# Create a PdfPages object to save the figures
from matplotlib.backends.backend_pdf import PdfPages
with PdfPages('model_check.pdf') as pdf:
    for img_id in test_id:
        model1_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model1.tif')
        model2_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model2.tif')
        model3_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model3.tif')
        model4_img = tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model4.tif')
        model1_name = models_name[shuffle_model[img_id][0]]
        model2_name = models_name[shuffle_model[img_id][1]]
        model3_name = models_name[shuffle_model[img_id][2]]
        model4_name = models_name[shuffle_model[img_id][3]]
        model_ori1 = models_map[shuffle_model[img_id][0]][img_id]
        model_ori2 = models_map[shuffle_model[img_id][1]][img_id]
        model_ori3 = models_map[shuffle_model[img_id][2]][img_id]
        model_ori4 = models_map[shuffle_model[img_id][3]][img_id]
        
        fig, ax = plt.subplots(2, 4, figsize=(20, 10))
        
        # Display the images
        ax[0][0].imshow(model1_img>0)
        ax[0][1].imshow(model2_img>0)
        ax[0][2].imshow(model3_img>0)
        ax[0][3].imshow(model4_img>0)

        ax[1][0].imshow(model_ori1)
        ax[1][1].imshow(model_ori2)
        ax[1][2].imshow(model_ori3)
        ax[1][3].imshow(model_ori4)
       
        # Set titles for each subplot
        ax[0][0].set_title(f'{img_id} Model 1({model1_name})')
        ax[0][1].set_title(f'{img_id} Model 2({model2_name})')
        ax[0][2].set_title(f'{img_id} Model 3({model3_name})')
        ax[0][3].set_title(f'{img_id} Model 4({model4_name})')
        
        # Adjust layout
        plt.tight_layout()
        
        # Save the current figure into the PDF
        pdf.savefig(fig)
        
        # Close the figure to free memory
        plt.close(fig)

print("PDF saved successfully.")
# Out:
# PDF saved successfully.

# %%
with open('/mnt/aperto/mxia/Tatz_annotations/models_select/model_select.pkl', 'rb') as f:
    model_select_data = pickle.load(f)

# %%
selected_columns = model_select_data[['ID','model_rank', 'comments']]
selected_columns
# Out:
#        ID                                         model_rank  \
# 5    0005                                      rank1: model3
# 6    0006                                      rank1: model2
# 9    0009                                      rank1: model4
# 17   0017                                      rank1: model1
# 22   0022                                      rank1: model4
# 24   0024                                           All same
# 30   0030                                rank1: model 1 or 4
# 33   0033                       rank1: model3, worst: model1
# 42   0042                               rank1: model 1 and 2
# 45   0045                                      rank1: model4
# 46   0046                                      Worst: model3
# 56   0056  None performed well. If I have to choose, mode...
# 59   0059                                rank1: model 1 or 2
# 60   0060                                      rank1: model1
# 63   0063                                      Worst: model1
# 66   0066                          rank1: model 4 or model 1
# 75   0075                                      rank1: model3
# 77   0077                                rank1: model 2 or 3
# 79   0079  rank1: model1, rank2: model 3, rank3: model 4,...
# 84   0084                                 All same, no cells
# 90   0090                      rank1: model 3 rank2: model 4
# 101  0101                                      rank1: model2
# 109  0109                                Hard to give a rank
# 113  0113          rank1: model 2 or 3, maybe model2 better?
# 117  0117                                      rank1: model3
# 118  0118                                       Hard to rank
# 119  0119                                rank1: model 3 or 4
# 124  0124                                      rank1: model3
# 125  0125                                    rank1: model 2
# 143  0143                                      rank1: model1
# 146  0146                                All models look bad
# 147  0147                           All models performed bad
# 158  0158                                      rank1: model1
# 159  0159  rank1: model1 but it still missed a lot of dim...
# 165  0165                          rank1: model 1 or model 2
# 168  0168                                      rank1: model1
# 172  0172                                      rank1: model2
# 176  0176             Hard to rank. Model 5 may be the best?
# 177  0177                          rank1: model 1 or model 3
# 181  0181                                      rank1: model3
# 183  0183                                     rank1: model 2
# 202  0202                                      rank1: model2
# 213  0213                           rank1: model 1 or model2
# 221  0221                                Hard to give a rank
# 227  0227                      rank1: model1, but it is poor
# 231  0231                               rank1: model 2, 3, 4
# 238  0238                   rank1: model3, but not excellent
# 244  0244                                      rank1: model2
# 246  0246                          rank1: other than model 3
# 260  0260                                rank1: model 1 or 4
# 269  0269                                rank1: model 2 or 3
# 271  0271                           rank1: model1 or model 3
# 274  0274                                      rank1: model4
# 275  0275                       rank1: model4, rank2: model2
# 277  0277                          rank1: model 1 or model 3
# 279  0279                       rank1: model4, worst: model3
# 281  0281                          rank1: model 1 or model 4
# 282  0282                                      rank1: model1
# 285  0285                                      rank1: model1
#
#                                               comments
# 5    Model 3 missed some but the best overall. Mode...
# 6    Model 2 detect well dim cells and can separate...
# 9    Model 4 looks great. Model 3 missed a cell whi...
# 17   Even the best model 1 missed dim cell. Model 2...
# 22   Though best, model 4 missed some dim cells. Mo...
# 24   No positive cells in the image. All models cor...
# 30   All model failed to detect dim cells. Model 2 ...
# 33   Model 3 did it correct. Model 1 detected too m...
# 42   The image includes no positive cells. Model 3,...
# 45   All model missed dim cells. Model 2 missed a b...
# 46   I believe the image contains zero positive cel...
# 56   Image is noisy with non-specifics. None detect...
# 59   Model 1 and 2 look identical. Though model 4 d...
# 60   Model 1 did it close. Model 3 and 4 have too m...
# 63   The image contains no positive cells. Model 2,...
# 66   Model 4 performed very good at detecting dim c...
# 75   Model 3 missed some positives. Model 4 is clos...
# 77   Model 2 and 3 have disagreement over dim cells...
# 79   model 1 did a decent job. model 3 is slightly ...
# 84    No cells in the image. All model did it correct.
# 90   model 3 slighltly outperforms model 4 in term ...
# 101  Model 2 missed cells at the edge. Other models...
# 109  Model 2 segments well in the crowdy area, but ...
# 113  model1 missed a lot of bright cells. model 2 m...
# 117  model3 missed some dim cells but did a good jo...
# 118  Some models ignore dim cells some models detec...
# 119  The image does not include any cells. Model 3 ...
# 124  model 3 successfully ignored the non-specifics...
# 125  model2 slightly outperformed the other because...
# 143  model1 detected well the dim cells while model...
# 146  Models either detected non-specifics or missed...
# 147  Same as previous task. The task is challenging...
# 158  model1 detected dim cells but it also showed o...
# 159  model1 segmentation looks more precise than ot...
# 165  All models missed dim cells. Model 1 and model...
# 168  Model 1 showed a decent performance. Model 2 i...
# 172  I need to see even larger field to judge if th...
# 176  Due to the lack of z-plane, even I cannot make...
# 177  Both model 1 and 3 showed very similar pattern...
# 181  model 2 and 4 picked up non-specifics. model 3...
# 183  The image is very challenging even for me, but...
# 202  The image is very challenging because of high-...
# 213  model 1 looks slightly better than model 2 bec...
# 221  If model 3 did not pick up false positives, th...
# 227  All models did it wrong by missing many positi...
# 231                model 1 detected non-positive cells
# 238  model 3 missed some obviously positive cells b...
# 244  Model 2 looks good. It missed a bit of positiv...
# 246  The image contains no cells. Only model 3 did ...
# 260  Both model 1 and 4 missed dim positive cells b...
# 269  model 2 has rough segmentation to merge two ce...
# 271  Both model 1 and 3 have similar performance an...
# 274  model 4 has slightly better in detection of di...
# 275  Model 4 did a decent job to detect very dim ce...
# 277  Model 1 looks very similar to model 3, but bot...
# 279  model 4 performed well in detection of dim cel...
# 281  Model 1 is more aggressive than model 4 to det...
# 282  Model1 did it correct while other models detec...
# 285  Model1 looks good. Some dim cells model 1 did ...

# %%
# Save the DataFrame as an Excel file
selected_columns.to_excel('./comments.xlsx', index=False)

# %%
rank = {'0005': [3],
        '0006' :[2],
        '0009':[4],
        '0017':[1],
        '0022':[4],
        '0024':[1,2,3,4],
        '0030':[1,4],
        '0033':{'best':[3],'worst':[1]},
        '0042':[1,2],
        '0045':[4],
        '0046':{'worst':[3]},
        '0056':{'best':[2,4],'comment':'None performed well. If I have to choose, model 2 or 4 is the best.'},
        '0059':[1,2],
        '0060':[1],
        '0063':{'best':[2,3,4],'worst':[1]},
        '0066':[4,1],
        '0075':[3],
        '0077':[2,3],
        '0079':{'best':[1],'worst':[2],'rank':[1,3,4,2]},
        '0084':[1,2,3,4],
        '0090':{'best':[3],'rank':[3,4]},
        '0101':[2],
        '0109':'NA',
        '0113':{'best':[2],'comment':'maybe 2 better'},
        '0117':[3],
        '0118':'NA',
        '0119':[3,4],
        '0124':[3],
        '0125':[2],
        '0143':[1],
        '0146':{'worst':[1,2,3,4]},
        '0147':{'worst':[1,2,3,4]},
        '0158':[1],
        '0159':{'best':[1], 'comment':'model1 but it still missed a lot of dim cells'},
        '0165':[1,2],
        '0168':[1],
        '0172':[2],
        '0176':{'comment':'Hard to rank. Model 5 may be the best?'},
        '0177':[1,3],
        '0181':[3],
        '0183':[2],
        '0202':[2],
        '0213':{'best':[1], 'comment':'model 1 looks slightly better than model 2 because it picked up more dim cells. It is hard to tell if those cells are non-specifics or not though.'},
        '0221':'NA',
        '0227':{'worst':[1,2,3,4],'comment':'model1 best, but it is poor'},
        '0231':[2,3,4],
        '0238':{'best':[3], 'comment':'But not excellent'},
        '0244':[2],
        '0246':{'best':[1,2,4],'worst': [3]},
        '0260':[1,4],
        '0269':[2,3],
        '0271':[1,3],
        '0274':[4],
        '0275':{'best':[4],'rank':[4,2]},
        '0277':[1,3],
        '0279':{'best':[4],'worst':[3]},
        '0281':[1,4],
        '0282':[1],
        '0285':[1]
}

# %%
rank_best = {}
rank_worst = {}
rank_comment = {}
rank_rank = {}
rank_NA = {}

for item in rank:
    if type(rank[item]) == list:
         rank_best[item] =  rank[item]
    if 'worst' in rank[item]:
        rank_worst[item] = rank[item]['worst']
        #print('worst:', item,rank[item]['worst'])
    if 'best' in rank[item]:
        rank_best[item] = rank[item]['best']
        #print('best:', item, rank[item]['best'])
    if 'comment' in rank[item]:
        rank_comment[item] = rank[item]['comment']
    if 'rank' in rank[item]:
        rank_rank[item] = rank[item]['rank']
    if rank[item] == 'NA':
        rank_NA[item] = 'NA'

# %%
rank_best_ori  =  {}

# %%
for img_id in rank_best:
    rank_best_ori[img_id] =  [models_name[shuffle_model[img_id][item-1]] for item in rank_best[img_id]]

# %%
rank_best_ori
# Out:
# {'0005': ['cellpose'],
#  '0006': ['cellpose'],
#  '0009': ['swin_3d_pretrain_win3'],
#  '0017': ['cellpose'],
#  '0022': ['stardist'],
#  '0024': ['swin2d', 'cellpose', 'stardist', 'swin_3d_pretrain_win3'],
#  '0030': ['stardist', 'swin_3d_pretrain_win3'],
#  '0033': ['swin_3d_pretrain_win3'],
#  '0042': ['swin2d', 'swin_3d_pretrain_win3'],
#  '0045': ['stardist'],
#  '0056': ['cellpose', 'swin2d'],
#  '0059': ['swin2d', 'swin_3d_pretrain_win3'],
#  '0060': ['swin2d'],
#  '0063': ['swin2d', 'swin_3d_pretrain_win3', 'cellpose'],
#  '0066': ['stardist', 'cellpose'],
#  '0075': ['stardist'],
#  '0077': ['swin_3d_pretrain_win3', 'swin2d'],
#  '0079': ['swin2d'],
#  '0084': ['cellpose', 'swin_3d_pretrain_win3', 'stardist', 'swin2d'],
#  '0090': ['stardist'],
#  '0101': ['swin2d'],
#  '0113': ['swin_3d_pretrain_win3'],
#  '0117': ['cellpose'],
#  '0119': ['swin_3d_pretrain_win3', 'swin2d'],
#  '0124': ['cellpose'],
#  '0125': ['cellpose'],
#  '0143': ['swin2d'],
#  '0158': ['swin2d'],
#  '0159': ['stardist'],
#  '0165': ['stardist', 'swin_3d_pretrain_win3'],
#  '0168': ['swin2d'],
#  '0172': ['stardist'],
#  '0177': ['swin2d', 'swin_3d_pretrain_win3'],
#  '0181': ['swin2d'],
#  '0183': ['cellpose'],
#  '0202': ['cellpose'],
#  '0213': ['stardist'],
#  '0231': ['swin2d', 'stardist', 'cellpose'],
#  '0238': ['cellpose'],
#  '0244': ['swin_3d_pretrain_win3'],
#  '0246': ['swin2d', 'cellpose', 'stardist'],
#  '0260': ['stardist', 'swin2d'],
#  '0269': ['swin_3d_pretrain_win3', 'stardist'],
#  '0271': ['swin2d', 'stardist'],
#  '0274': ['swin2d'],
#  '0275': ['stardist'],
#  '0277': ['stardist', 'swin2d'],
#  '0279': ['swin2d'],
#  '0281': ['stardist', 'cellpose'],
#  '0282': ['swin2d'],
#  '0285': ['swin_3d_pretrain_win3']}

# %%
cellpose_win = 0
stardist_win = 0
swin2d_win = 0
swin3d_win = 0
for item in rank_best_ori:
    if 'cellpose' in rank_best_ori[item]:
        cellpose_win += 1
    if 'stardist' in rank_best_ori[item]:
        stardist_win += 1
    if 'swin2d' in rank_best_ori[item]:
        swin2d_win += 1
    if 'swin_3d_pretrain_win3' in rank_best_ori[item]:
       
        swin3d_win += 1

# %%
###win time plot

import matplotlib.pyplot as plt

# Example data
categories = ['cellpose', 'stardist', 'swin2d', 'swin3dwin3']
values = [cellpose_win, stardist_win, swin2d_win, swin3d_win]

# Creating the bar plot
plt.bar(categories, values, color='blue')

# Adding titles and labels
plt.title('Best model time')
plt.xlabel('Categories')
plt.ylabel('Values')

# Display the plot
plt.show()

# %%
rank_worst_ori = {}

# %%
for img_id in rank_worst:
    rank_worst_ori[img_id] =  [models_name[shuffle_model[img_id][item-1]] for item in rank_worst[img_id]]

# %%
rank_worst_ori
# Out:
# {'0033': ['cellpose'],
#  '0046': ['stardist'],
#  '0063': ['stardist'],
#  '0079': ['cellpose'],
#  '0146': ['swin_3d_pretrain_win3', 'cellpose', 'stardist', 'swin2d'],
#  '0147': ['cellpose', 'swin2d', 'stardist', 'swin_3d_pretrain_win3'],
#  '0227': ['stardist', 'swin_3d_pretrain_win3', 'cellpose', 'swin2d'],
#  '0246': ['swin_3d_pretrain_win3'],
#  '0279': ['stardist']}

# %%
cellpose_lose = 0
stardist_lose = 0
swin2d_lose = 0
swin3d_lose = 0
for item in rank_worst_ori:
    if 'cellpose' in rank_worst_ori[item]:
        cellpose_lose += 1
    if 'stardist' in rank_worst_ori[item]:
        stardist_lose += 1
    if 'swin2d' in rank_worst_ori[item]:
        swin2d_lose += 1
    if 'swin_3d_pretrain_win3' in rank_worst_ori[item]:
       
        swin3d_lose += 1

# %%
###lose time plot

import matplotlib.pyplot as plt

# Example data
categories = ['cellpose', 'stardist', 'swin2d', 'swin3dwin3']
values = [cellpose_lose, stardist_lose, swin2d_lose, swin3d_lose]

# Creating the bar plot
plt.bar(categories, values, color='blue')

# Adding titles and labels
plt.title('Worst model time')
plt.xlabel('Categories')
plt.ylabel('Values')

# Display the plot
plt.show()

# %%
rank_comment
# Out:
# {'0056': 'None performed well. If I have to choose, model 2 or 4 is the best.',
#  '0113': 'maybe 2 better',
#  '0159': 'model1 but it still missed a lot of dim cells',
#  '0176': 'Hard to rank. Model 5 may be the best?',
#  '0213': 'model 1 looks slightly better than model 2 because it picked up more dim cells. It is hard to tell if those cells are non-specifics or not though.',
#  '0227': 'model1 best, but it is poor',
#  '0238': 'But not excellent'}

# %%
rank_NA
# Out:
# {'0109': 'NA', '0118': 'NA', '0221': 'NA'}

# %%
rank_rank
# Out:
# {'0079': [1, 3, 4, 2], '0090': [3, 4], '0275': [4, 2]}

# %%
rank_rank_ori = {}
for img_id in rank_rank:
    rank_rank_ori[img_id] =  [models_name[shuffle_model[img_id][item-1]] for item in rank_rank[img_id]]

# %%
rank = rank_rank_ori

# %%
rank
# Out:
# {'0079': ['swin2d', 'swin_3d_pretrain_win3', 'stardist', 'cellpose'],
#  '0090': ['stardist', 'swin2d'],
#  '0275': ['stardist', 'swin_3d_pretrain_win3']}

# %%
import matplotlib.pyplot as plt 
# Create a PdfPages object to save the figures
from matplotlib.backends.backend_pdf import PdfPages
with PdfPages('model_ori_order.pdf') as pdf:
   for img_id in test_id:

        if img_id in rank_best_ori:
            
        model_img = [ tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model1.tif'),
                      tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model2.tif'),
                      tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model3.tif'),
                      tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model4.tif')]
        
        
         
        model_ori1 = cellpose_data[img_id]
        model_ori2 = stardist_data[img_id]
        model_ori3 = swin2d_predict[img_id]
        model_ori4 = swin_3D_pretrain_window3_predict[img_id]

        ##### change order
        cellpose = model_img[shuffle_model[img_id].index(1)]
        stardist = model_img[shuffle_model[img_id].index(2)]
        swin2d = model_img[shuffle_model[img_id].index(3)]
        swin3d_win3 = model_img[shuffle_model[img_id].index(4)]
        
        fig, ax = plt.subplots(2, 4, figsize=(20, 10))
        
        # Display the images
        ax[0][0].imshow(cellpose>0)
        ax[0][1].imshow(stardist>0)
        ax[0][2].imshow(swin2d>0)
        ax[0][3].imshow(swin3d_win3>0)

        ax[1][0].imshow(model_ori1)
        ax[1][1].imshow(model_ori2)
        ax[1][2].imshow(model_ori3)
        ax[1][3].imshow(model_ori4)
       
        # Set titles for each subplot
        ax[0][0].set_title(f'{img_id} cellpose ')
        ax[0][1].set_title(f'{img_id} stardist')
        ax[0][2].set_title(f'{img_id} swin2d')
        ax[0][3].set_title(f'{img_id} swin3d_win3')
        # Adjust layout
        plt.tight_layout()
        
        # Save the current figure into the PDF
        pdf.savefig(fig)
        
        # Close the figure to free memory
        plt.close(fig)

print("PDF saved successfully.")
# Out:
# PDF saved successfully.

# %%
import matplotlib.pyplot as plt 
# Create a PdfPages object to save the figures
from matplotlib.backends.backend_pdf import PdfPages
with PdfPages('model_masks.pdf') as pdf:
   for img_id in test_id:
            
        model_img = [ tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model1.tif'),
                      tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model2.tif'),
                      tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model3.tif'),
                      tf.imread(f'/mnt/aperto/mxia/Tatz_annotations/models_select/{img_id}_model4.tif')]
        
        mask = tf.imread(f'/mnt/aperto/yin/cellpose_training/data/test/{img_id}_mask.tif')

        ##### change order
        cellpose = model_img[shuffle_model[img_id].index(1)]
        stardist = model_img[shuffle_model[img_id].index(2)]
        swin2d = model_img[shuffle_model[img_id].index(3)]
        swin3d_win3 = model_img[shuffle_model[img_id].index(4)]
        
        fig, ax = plt.subplots(1, 5, figsize=(25, 5))
        
        # Display the images
        ax[0].imshow(cellpose>0)
        ax[1].imshow(stardist>0)
        ax[2].imshow(swin2d>0)
        ax[3].imshow(swin3d_win3>0)
        ax[4].imshow(mask>0)

       
        # Set titles for each subplot
        ax[0].set_title(f'{img_id} cellpose ')
        ax[1].set_title(f'{img_id} stardist')
        ax[2].set_title(f'{img_id} swin2d')
        ax[3].set_title(f'{img_id} swin3d_win3')
        ax[4].set_title(f'{img_id} Yuchen annotate')
        # Adjust layout
        plt.tight_layout()
        
        # Save the current figure into the PDF
        pdf.savefig(fig)
        
        # Close the figure to free memory
        plt.close(fig)

print("PDF saved successfully.")
# Out:
# PDF saved successfully.

# %% [markdown]
# ### Get rank best metrics

# %%
rank_best
# Out:
# {'0005': [3],
#  '0006': [2],
#  '0009': [4],
#  '0017': [1],
#  '0022': [4],
#  '0024': [1, 2, 3, 4],
#  '0030': [1, 4],
#  '0033': [3],
#  '0042': [1, 2],
#  '0045': [4],
#  '0056': [2, 4],
#  '0059': [1, 2],
#  '0060': [1],
#  '0063': [2, 3, 4],
#  '0066': [4, 1],
#  '0075': [3],
#  '0077': [2, 3],
#  '0079': [1],
#  '0084': [1, 2, 3, 4],
#  '0090': [3],
#  '0101': [2],
#  '0113': [2],
#  '0117': [3],
#  '0119': [3, 4],
#  '0124': [3],
#  '0125': [2],
#  '0143': [1],
#  '0158': [1],
#  '0159': [1],
#  '0165': [1, 2],
#  '0168': [1],
#  '0172': [2],
#  '0177': [1, 3],
#  '0181': [3],
#  '0183': [2],
#  '0202': [2],
#  '0213': [1],
#  '0231': [2, 3, 4],
#  '0238': [3],
#  '0244': [2],
#  '0246': [1, 2, 4],
#  '0260': [1, 4],
#  '0269': [2, 3],
#  '0271': [1, 3],
#  '0274': [4],
#  '0275': [4],
#  '0277': [1, 3],
#  '0279': [4],
#  '0281': [1, 4],
#  '0282': [1],
#  '0285': [1]}

# %%
best_model_predict = {}
for item in rank_best:
    best_model_predict[item] = shuffle_model[item][rank_best[item][0]]
